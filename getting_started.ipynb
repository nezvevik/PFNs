# %% [markdown]
# **In order to get the fastest trainings you need to enable GPUs for the notebook:**
# * Navigate to Edit→Notebook Settings
# * select GPU from the Hardware Accelerator drop-down
# (https://colab.research.google.com/notebooks/gpu.ipynb#scrollTo=oM_8ELnJq_wd)

# %%
# Some installations upfront
# !git clone https://github.com/automl/PFNs.git
# !cd PFNs; pip install -e .; cd -
# Out:
# fatal: destination path 'PFNs' already exists and is not an empty directory.
# Obtaining file:///content/PFNs
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: black==24.4.2 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (24.4.2)
# Requirement already satisfied: configspace>=0.4.21 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (1.2.2)
# Requirement already satisfied: einops>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (0.8.1)
# Requirement already satisfied: flake8-bugbear>=24.0.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (25.11.29)
# Requirement already satisfied: gpytorch>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (1.15.1)
# Requirement already satisfied: matplotlib>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (3.10.8)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (2.0.2)
# Requirement already satisfied: pre-commit>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (4.5.1)
# Requirement already satisfied: pytest>=5.4.3 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (8.4.2)
# Requirement already satisfied: pyyaml>=5.4.1 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (2.32.4)
# Requirement already satisfied: ruff-api==0.1.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (0.1.0)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (1.6.1)
# Requirement already satisfied: stdlibs==2024.1.28 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (2024.1.28)
# Requirement already satisfied: tensorboard>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (2.20.0)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (2.9.0+cu126)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (4.67.1)
# Requirement already satisfied: usort==1.0.8.post1 in /usr/local/lib/python3.12/dist-packages (from pfns==0.4.2) (1.0.8.post1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black==24.4.2->pfns==0.4.2) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black==24.4.2->pfns==0.4.2) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.12/dist-packages (from black==24.4.2->pfns==0.4.2) (25.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from black==24.4.2->pfns==0.4.2) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black==24.4.2->pfns==0.4.2) (4.5.1)
# Requirement already satisfied: attrs>=21.2.0 in /usr/local/lib/python3.12/dist-packages (from usort==1.0.8.post1->pfns==0.4.2) (25.4.0)
# Requirement already satisfied: LibCST>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from usort==1.0.8.post1->pfns==0.4.2) (1.8.6)
# Requirement already satisfied: moreorless>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from usort==1.0.8.post1->pfns==0.4.2) (0.5.0)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from usort==1.0.8.post1->pfns==0.4.2) (0.10.2)
# Requirement already satisfied: trailrunner>=1.0 in /usr/local/lib/python3.12/dist-packages (from usort==1.0.8.post1->pfns==0.4.2) (1.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from configspace>=0.4.21->pfns==0.4.2) (3.3.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from configspace>=0.4.21->pfns==0.4.2) (1.16.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from configspace>=0.4.21->pfns==0.4.2) (4.15.0)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from configspace>=0.4.21->pfns==0.4.2) (10.8.0)
# Requirement already satisfied: flake8>=7.2.0 in /usr/local/lib/python3.12/dist-packages (from flake8-bugbear>=24.0.0->pfns==0.4.2) (7.3.0)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.5.0->pfns==0.4.2) (0.3.5)
# Requirement already satisfied: mpmath<=1.3,>=0.19 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.5.0->pfns==0.4.2) (1.3.0)
# Requirement already satisfied: linear_operator>=0.6 in /usr/local/lib/python3.12/dist-packages (from gpytorch>=1.5.0->pfns==0.4.2) (0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.1->pfns==0.4.2) (2.9.0.post0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->pfns==0.4.2) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->pfns==0.4.2) (2.6.16)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->pfns==0.4.2) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->pfns==0.4.2) (20.36.1)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4.3->pfns==0.4.2) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4.3->pfns==0.4.2) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4.3->pfns==0.4.2) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->pfns==0.4.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->pfns==0.4.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->pfns==0.4.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->pfns==0.4.2) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.2->pfns==0.4.2) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.2->pfns==0.4.2) (3.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (75.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.20.0->pfns==0.4.2) (3.1.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (3.20.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->pfns==0.4.2) (3.5.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from flake8>=7.2.0->flake8-bugbear>=24.0.0->pfns==0.4.2) (0.7.0)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from flake8>=7.2.0->flake8-bugbear>=24.0.0->pfns==0.4.2) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from flake8>=7.2.0->flake8-bugbear>=24.0.0->pfns==0.4.2) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10.1->pfns==0.4.2) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->pfns==0.4.2) (0.4.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.20.0->pfns==0.4.2) (3.0.3)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping->gpytorch>=1.5.0->pfns==0.4.2) (0.1.7)
# Building wheels for collected packages: pfns
#   Building editable for pfns (pyproject.toml) ... done
#   Created wheel for pfns: filename=pfns-0.4.2-py3-none-any.whl size=7856 sha256=6d694c2046379aa22a1962299ddc788a09f71bfaf1a28ca0a28d68e3d97d17e6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f72sdlnb/wheels/bc/60/a7/723f250656dc79097d6a23c95a4e6d3949685d9bd67c0db6ab
# Successfully built pfns
# Installing collected packages: pfns
#   Attempting uninstall: pfns
#     Found existing installation: pfns 0.4.2
#     Uninstalling pfns-0.4.2:
#       Successfully uninstalled pfns-0.4.2
# Successfully installed pfns-0.4.2
# /content

# %%
# if this import fails, please restart the notebook:
# 1. click on "Runtime"
# 2. click "Restart session"
try:
    import pfns
except ImportError:
    raise ImportError("Please restart runtime by i) clicking on \'Runtime\' and then ii) clicking \'Restart session\'")

# %%
from pfns.priors import Batch
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ## Let's train our first PFN to do ridge regression

# %%
def get_batch_poly(batch_size=2, seq_len=100, num_features=1,
                   degree=12, hyperparameters=None, device='cpu', **kwargs):
    if hyperparameters is None:
        hyperparameters = {'a': 0.1, 'b': 0.1}

    xs = torch.rand(batch_size, seq_len, num_features)
    t = 2*xs - 1  # shape (batch, seq, num_features), for num_features=1

    # build Chebyshev T_k(t) recursively (k=0..degree)
    T0 = torch.ones_like(t[..., :1])
    T1 = t[..., :1]
    cheb = [T1]  # start from k=1

    prev2, prev1 = T0, T1
    for _k in range(2, degree + 1):
        Tk = 2*t[..., :1]*prev1 - prev2
        cheb.append(Tk)
        prev2, prev1 = prev1, Tk

    phi_x = torch.cat(cheb + [torch.ones_like(t[..., :1])], dim=-1)

    ws = torch.distributions.Normal(
        torch.zeros(phi_x.shape[-1]), hyperparameters['b']
    ).sample((batch_size,))

    ys = torch.distributions.Normal(
        torch.einsum('nmf,nf->nm', phi_x, ws),
        hyperparameters['a']
    ).sample()[..., None]

    return Batch(x=xs.to(device), y=ys.to(device), target_y=ys.to(device))

batch = get_batch_poly(batch_size=3, seq_len=200, degree=12)
for dataset_index in range(len(batch.x)):
    plt.scatter(batch.x[dataset_index,:,0].numpy(), batch.y[dataset_index,:].numpy())

# %%
def get_batch_sin(batch_size=10,seq_len=100,num_features=1,
                                             hyperparameters=None, **kwargs):
    if hyperparameters is None:
        hyperparameters = {'a': 0.01, 'b': 1.0, 's': .3, 's_freq': 40.0}
    ws = torch.distributions.Normal(torch.zeros(num_features+1), hyperparameters['b']).sample((batch_size,))

    xs = torch.rand(batch_size, seq_len, num_features)
    mean_ys = torch.einsum('nmf, nf -> nm',
                     torch.cat([xs,torch.ones(batch_size, seq_len,1)],2),
                     ws
                    )
    ys = torch.distributions.Normal(
        mean_ys,
        hyperparameters['a']
    ).sample()

    freq_w = torch.distributions.Normal(
        torch.ones(num_features)*hyperparameters['s_freq'], 10.0
    ).sample((batch_size,))

    print(freq_w)

    ys += torch.sin(xs[...,0]*freq_w) * hyperparameters['s']


    return Batch(x=xs, y=ys[...,None], target_y=mean_ys[...,None])

batch = get_batch_sin(batch_size=3, seq_len=200, degree=12)
for dataset_index in range(len(batch.x)):
    plt.scatter(batch.x[dataset_index,:,0].numpy(), batch.y[dataset_index,:].numpy())
# Out:
# tensor([[37.7276],
#         [38.3549],
#         [43.9137]])

# %% [markdown]
# ## Train Train Train!!!
#
# ### Let's train a mini PFN for 1D datasets with up to 20 elements 🚀
#
# This should take around 1 minute, at least on my machine it does.
#
# #### What happens during training?
# During training we sample datasets from our `get_batch` method, we then split them into left and right of the so called `single_eval_pos` (which in turn is sampled uniformly at random). If something is left it is training, on the right it is test. Now our PFN is training to predict the $y$ of the test set, given $x$ and $y$ for the training set, as well as $x$ for the test set.
#
# Our training uses standard Adam and a cross-entropy loss. We use a transformer as PFN, where each example in the training or test set is encoded as a token (sometimes also called time step). More info on the architecture can be found in our paper.

# %%
import math

from torch import nn
from pfns import utils
from pfns.model import bar_distribution
from pfns.train import train, MainConfig, OptimizerConfig, TransformerConfig, BatchShapeSamplerConfig
from pfns.model.encoders import EncoderConfig
from pfns.model.bar_distribution import BarDistributionConfig
from pfns.priors.prior import AdhocPriorConfig

# Let's fix some global settings

hps = None
num_features = 1
max_dataset_size = 20



def train_a_pfn(get_batch_function, epochs=10, num_features=num_features, max_dataset_size=max_dataset_size, hps=hps, batch_size=256, steps_per_epoch=100):

    # define a bar distribution (riemann distribution) criterion with 1000 bars
    ys = get_batch_function(100000,20, num_features, hyperparameters=hps).target_y
    # we define our bar distribution adaptively with respect to the above sample of target ys from our prior
    borders = bar_distribution.get_bucket_borders(num_outputs=1_000, ys=ys).tolist()

    config = MainConfig(
        priors=[AdhocPriorConfig(get_batch_methods=[get_batch_function], prior_kwargs={'num_features': num_features, 'hyperparameters': hps})],
        optimizer=OptimizerConfig('adamw', lr=.0003),
        model=TransformerConfig(
            criterion=BarDistributionConfig(full_support=True, borders=borders),
            emsize=512, nhead=8, nhid=1024, nlayers=6,
            features_per_group=1, attention_between_features=False,
            # The encoder config ensures the uniform inputs between 0 and 1 have mean 0 and var 1
            encoder=EncoderConfig(constant_normalization_mean=.5, constant_normalization_std=math.sqrt(1/12),)
        ),
        batch_shape_sampler=BatchShapeSamplerConfig(batch_size=batch_size, max_seq_len=max_dataset_size,
                                                    min_num_features=num_features, max_num_features=num_features),
        epochs=epochs, warmup_epochs=epochs//4, steps_per_epoch=steps_per_epoch,
        num_workers=0,
    )
    train_result = train(config, device='cuda', reusable_config=False)
    return train_result

# %%
model_poly = train_a_pfn(get_batch_poly)['model']
# Out:
# init dist
# Not using distributed
# ALL: Using device cuda.
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_ridge_regression (batch_size=2, seq_len=100, num_features=1, hyperparameters=None, device='cpu', **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=256, min_single_eval_pos=0, max_seq_len=20, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': True, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_ridge_regression (batch_size=2, seq_len=100, num_features=1, hyperparameters=None, device='cpu', **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=256, min_single_eval_pos=0, max_seq_len=20, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': False, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# Using linear y encoder, as no y_encoder was provided.
# Using a Transformer with 14.14 M parameters
# Checkpoint file None not found or load/save paths are identical and file doesn't exist. Starting from scratch.
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  5.55s | mean loss  1.60 | lr 0.0 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 75.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  5.23s | mean loss  0.68 | lr 0.00015 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 76.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  5.05s | mean loss -0.03 | lr 0.0003 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 78.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  5.26s | mean loss -0.22 | lr 0.000288581929876693 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 65.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  5.05s | mean loss -0.41 | lr 0.00025606601717798207 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 76.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  5.11s | mean loss -0.38 | lr 0.00020740251485476345 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 74.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  5.26s | mean loss -0.44 | lr 0.00015 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  5.08s | mean loss -0.52 | lr 9.259748514523653e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 79.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  5.32s | mean loss -0.40 | lr 4.3933982822017876e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  5.14s | mean loss -0.47 | lr 1.1418070123306989e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 76.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------

# %%
model_sin = train_a_pfn(get_batch_sin)['model']

# %% [markdown]
# ### Analysis of the performance of our trained PFN

# %%
# let's sample some datasets to look at
batch = get_batch_for_ridge_regression(seq_len=100, hyperparameters=hps, batch_size=10)

# %%
print(batch.x.shape)
print(batch.y.shape)
print(batch.target_y.shape)

x = batch.x
y = batch.y

with torch.no_grad():
    # we add our batch dimension, as our transformer always expects that
    logits = trained_model(x, y, x)
print(logits.shape)
# Out:
# torch.Size([10, 100, 1])
# torch.Size([10, 100, 1])
# torch.Size([10, 100, 1])
# torch.Size([10, 100, 1000])

# %%
# our model wants the seq dimension first, remember that!

batch_index = 0 # change this to see other examples
num_training_points = 4


train_x = batch.x[batch_index, :num_training_points]
train_y = batch.y[batch_index, :num_training_points]
test_x = batch.x[batch_index]

print(train_x.shape, train_y.shape, test_x.shape)

with torch.no_grad():
    # we add our batch dimension, as our transformer always expects that
    logits = trained_model(train_x[None], train_y[None], test_x[None])

# the model has the criterion still attached (it is the same though, as our criterion above)
# the criterion has a lot of handy function to use these logits
pred_means = trained_model.criterion.mean(logits)[0]
pred_confs = trained_model.criterion.quantile(logits)[0]


plt.scatter(train_x[...,0],train_y)
order_test_x = test_x[...,0].argsort()
plt.plot(test_x[order_test_x, ..., 0],pred_means[order_test_x], color='green', label='pfn')
plt.fill_between(test_x[order_test_x,0], pred_confs[...,0][order_test_x], pred_confs[...,1][order_test_x], alpha=.1, color='green')

import sklearn.linear_model

ridge_model = sklearn.linear_model.Ridge(alpha=(a/b)**2)
ridge_model.fit(train_x,train_y)
plt.plot(test_x[order_test_x].squeeze(), ridge_model.predict(test_x[order_test_x]), label='ridge regression')
plt.legend()
plt.plot();
# Out:
# torch.Size([4, 1]) torch.Size([4, 1]) torch.Size([100, 1])

# %%
import torch
def compute_nll(model, batch, eps=1e-12):
    x = batch.x.transpose(0, 1)
    y = batch.y.transpose(0, 1)
    target_y = batch.target_y.transpose(0, 1)

    with torch.no_grad():
      logits = model(x, y, x)

      borders = model.criterion.borders.to(logits.device)
      bin_centers = 0.5 * (borders[:-1] + borders[1:])


      probs = torch.softmax(logits, dim=-1)
      bin_widths = borders[1:] - borders[:-1]

      bin_idx = torch.bucketize(
          target_y.squeeze(-1),
          borders
      ) - 1

      bin_idx = bin_idx.clamp(0, bin_widths.shape[0] - 1)

      probs_correct = probs.gather(
          dim=-1,
          index=bin_idx.unsqueeze(-1)
      ).squeeze(-1)

      widths = bin_widths[bin_idx]
      density = probs_correct / widths

      nll = -torch.log(density + eps)
      nll = nll.mean().item()

    return nll
print(compute_nll(trained_model, batch))

def compute_mse_loss(model, batch):
    x = batch.x.transpose(0, 1)
    y = batch.y.transpose(0, 1)
    target_y = batch.target_y.transpose(0, 1)

    with torch.no_grad():
        logits = model(x, y, x)  # (

        probs = torch.softmax(logits, dim=-1)

        borders = model.criterion.borders.to(logits.device)
        bin_centers = 0.5 * (borders[:-1] + borders[1:])

        pred_mean = torch.sum(
            probs * bin_centers.view(1, 1, -1),
            dim=-1,
            keepdim=True
        )

        mse = torch.mean((pred_mean - target_y) ** 2).item()

    return mse


compute_mse_loss(trained_model, batch)
# Out:
# 6.964451313018799
# 1.1106396913528442

# %% [markdown]
# Our model uses a Riemann distribution, that is a discretized distribution internally. We can show this here for one prediction.

# %% [markdown]
# ### They seem to align kinda well..
#
# .. at least for a PFN trained for 1 minute. If you are now interested in the more theoretical analysis why this prior yields ridge regression, please see https://statisticaloddsandends.wordpress.com/2018/12/29/bayesian-interpretation-of-ridge-regression/.
#
# What we can also see is that our PFN provides us with confidence bounds, unlike ridge regression. This is actually the case out of the box. We use a discretized distribution (the riemann distribution). It can be described as
# a piece-wise constant distribution. We just need to find out what good pieces are for our prior.
# You can view the discretization in `trained_model.criterion.borders`. We fit them on a lot of samples from our prior.
# If you are interested in the way we do regression, see read about the Riemann distribution in our paper https://arxiv.org/abs/2112.10510 or see the code in `bar_distribution.py`.

# %% [markdown]
# ## Let's do some special stuff!!
#
# So far we only reproduced an algorithm that already exists.
# Let's try two more things.

# %% [markdown]
# ### i) Sine Ridge Regression
#
#
# What should **sine ridge regression** be!? It is the same as ridge regression, just that
# we replace our curves with sines.
#
# We can adapt the `get_batch` function from above to get there.

# %%
def get_batch_for_sine_ridge_regression(batch_size=10,seq_len=100,num_features=1,
                                   hyperparameters=None, **kwargs):
    if hyperparameters is None:
        hyperparameters = {'a': 0.01, 'b': 1.0, 's': .3}
    ws = torch.distributions.Normal(torch.zeros(num_features+1), hyperparameters['b']).sample((batch_size,))

    xs = torch.rand(batch_size, seq_len, num_features)
    ys = torch.distributions.Normal(
        torch.einsum('nmf, nf -> nm',
                     torch.cat([xs,torch.ones(batch_size, seq_len,1)],2),
                     ws
                    ),
        hyperparameters['a']
    ).sample()

    ## the new part

    ys += torch.sin(xs[...,0]*20) * hyperparameters['s']

    ## end new part

    # get_batch functions return two different ys, let's come back to this later, though.
    return Batch(x=xs, y=ys[...,None], target_y=ys[...,None])

# %% [markdown]
# Let's sample from this prior...

# %%
batch = get_batch_for_sine_ridge_regression()
for dataset_index in range(len(batch.x)):
    plt.scatter(batch.x[dataset_index,:,0].numpy(), batch.y[dataset_index,:].numpy())

# %% [markdown]
# #### Funky curves, let's train a PFN!!!

# %%
train_results_sine = train_a_pfn(get_batch_for_sine_ridge_regression, epochs=20)
trained_model_sine = train_results_sine['model']
# Out:
# init dist
# Not using distributed
# ALL: Using device cuda.
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_sine_ridge_regression (batch_size=10, seq_len=100, num_features=1, hyperparameters=None, **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=256, min_single_eval_pos=0, max_seq_len=20, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': True, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_sine_ridge_regression (batch_size=10, seq_len=100, num_features=1, hyperparameters=None, **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=256, min_single_eval_pos=0, max_seq_len=20, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': False, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# Using linear y encoder, as no y_encoder was provided.
# Using a Transformer with 14.14 M parameters
# Checkpoint file None not found or load/save paths are identical and file doesn't exist. Starting from scratch.
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  6.53s | mean loss  1.60 | lr 0.0 | data time  0.00 step time  0.06 forward time  0.02 | max gpu mem 0.7 GiB | gpu utilization 74.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  5.30s | mean loss  1.05 | lr 5.9999999999999995e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  5.13s | mean loss  0.24 | lr 0.00011999999999999999 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 72.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  5.16s | mean loss  0.01 | lr 0.00017999999999999998 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 67.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  5.24s | mean loss -0.17 | lr 0.00023999999999999998 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 74.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  5.13s | mean loss -0.15 | lr 0.0003 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 76.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  5.33s | mean loss -0.30 | lr 0.0002967221401100708 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  5.10s | mean loss -0.55 | lr 0.0002870318186463901 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  5.30s | mean loss -0.46 | lr 0.0002713525491562421 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 76.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  5.10s | mean loss -0.56 | lr 0.0002503695909538287 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  5.18s | mean loss -0.89 | lr 0.000225 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 72.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time:  5.19s | mean loss -0.91 | lr 0.0001963525491562421 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time:  5.06s | mean loss -1.02 | lr 0.000165679269490148 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  5.30s | mean loss -1.28 | lr 0.000134320730509852 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 75.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  5.06s | mean loss -1.14 | lr 0.0001036474508437579 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time:  5.27s | mean loss -1.47 | lr 7.500000000000002e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time:  5.93s | mean loss -1.47 | lr 4.963040904617131e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 78.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  5.35s | mean loss -1.48 | lr 2.8647450843757897e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 75.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  5.10s | mean loss -1.58 | lr 1.2968181353609852e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 73.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  5.19s | mean loss -1.50 | lr 3.2778598899291465e-06 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.7 GiB | gpu utilization 70.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------

# %%
batch = get_batch_for_sine_ridge_regression(seq_len=300)
# batch = get_batch_for_ridge_regression(seq_len=100, hyperparameters=hps, batch_size=10)

# %%
# our model wants the seq dimension first, remember that!

batch_index = 2 # change this to see other examples
num_training_points = 20

train_x = batch.x[batch_index,:num_training_points]
train_y = batch.y[batch_index, :num_training_points]
test_x = batch.x[batch_index]

with torch.no_grad():
    # we add our batch dimension, as our transformer always expects that

    logits = trained_model_sine(train_x[None], train_y[None], test_x[None])
# the model has the criterion still attached (it is the same though, as our criterion above)
# the criterion has a lot of handy function to use these logits
pred_means = trained_model_sine.criterion.mean(logits)[0]
pred_confs = trained_model_sine.criterion.quantile(logits)[0]


plt.scatter(train_x[...,0],train_y)
order_test_x = test_x[...,0].argsort()
plt.plot(test_x[order_test_x],pred_means[order_test_x], color='green', label='pfn')
plt.fill_between(test_x[order_test_x,0], pred_confs[..., 0][order_test_x], pred_confs[...,1][order_test_x], alpha=.1, color='green')

# %% [markdown]
# We can see that the predictions appear, as we expect it, in a sine shape, too.

# %% [markdown]
# ### ii) Anti-sine Regression. Let's play with `batch.target_y`
#
# In all `get_batch` functions so far we specified two `y`s. We did this because there is a difference in how they are treated by the training loop. `batch.y` is used to feed it to the PFN as knowledge about the training set, while `batch.target_y` is used to train the transformer to predict it.
#
# Typically we use a different `batch.target_y` s.t. we train not to fit the noise. In EI for example one often prefers EI over predictions that do not take inherent noise into account, as that changes the confidence intervals.
#
# We will use the same prior as before, but make our model predict the middle of the sine wave instead of the wave itself.

# %%
def get_batch_for_anti_sine_ridge_regression(batch_size=10,seq_len=100,num_features=1,
                                             hyperparameters=None, **kwargs):
    if hyperparameters is None:
        hyperparameters = {'a': 0.01, 'b': 1.0, 's': .3}
    ws = torch.distributions.Normal(torch.zeros(num_features+1), hyperparameters['b']).sample((batch_size,))

    xs = torch.rand(batch_size, seq_len, num_features)
    mean_ys = torch.einsum('nmf, nf -> nm',
                     torch.cat([xs,torch.ones(batch_size, seq_len,1)],2),
                     ws
                    )
    ys = torch.distributions.Normal(
        mean_ys,
        hyperparameters['a']
    ).sample()


    ys += torch.sin(xs[...,0]*20) * hyperparameters['s']


    # the new part is in target_y
    return Batch(x=xs, y=ys[...,None], target_y=mean_ys[...,None])

# %% [markdown]
# Let's visualize this for one example:

# %%
batch = get_batch_for_anti_sine_ridge_regression()

plt.scatter(batch.x[dataset_index,:,0].numpy(), batch.y[dataset_index].numpy(), label='y')
plt.scatter(batch.x[dataset_index,:,0].numpy(), batch.target_y[dataset_index].numpy(), label='target_y')

plt.legend()
plt.show()

# %%
# we use a large max_dataset_size s.t. we can show it with more training examples, which makes the effect more clear
train_results_anti_sine = train_a_pfn(get_batch_for_anti_sine_ridge_regression, batch_size=64, max_dataset_size=100)
trained_model_anti_sine = train_results_anti_sine['model']
# Out:
# init dist
# Not using distributed
# ALL: Using device cuda.
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_anti_sine_ridge_regression (batch_size=10, seq_len=100, num_features=1, hyperparameters=None, **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=64, min_single_eval_pos=0, max_seq_len=100, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': True, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# DataLoader.__dict__ {'get_batch_method': functools.partial(get_batch_sequence(
# 	<__main__.get_batch_for_anti_sine_ridge_regression (batch_size=10, seq_len=100, num_features=1, hyperparameters=None, **kwargs)
# ), num_features=1, hyperparameters=None), 'num_steps': 100, 'batch_shape_sampler_function': <bound method BatchShapeSamplerConfig.sample_batch_shape of BatchShapeSamplerConfig(batch_size=64, min_single_eval_pos=0, max_seq_len=100, min_num_features=1, max_num_features=1, fixed_num_test_instances=None, seed=42)>, 'num_workers': 0, 'persistent_workers': False, 'get_batch_kwargs': {'device': 'cuda', 'n_targets_per_input': 1}, 'epoch_count': 0, 'importance_sampling_infos': None}
# Using linear y encoder, as no y_encoder was provided.
# Using a Transformer with 14.14 M parameters
# Checkpoint file None not found or load/save paths are identical and file doesn't exist. Starting from scratch.
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  6.55s | mean loss  1.59 | lr 0.0 | data time  0.00 step time  0.06 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 78.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  5.87s | mean loss  0.40 | lr 0.00015 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  5.72s | mean loss -0.30 | lr 0.0003 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 79.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  5.96s | mean loss -0.78 | lr 0.000288581929876693 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 82.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  5.74s | mean loss -0.88 | lr 0.00025606601717798207 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 80.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  5.94s | mean loss -1.05 | lr 0.00020740251485476345 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 81.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  5.88s | mean loss -1.22 | lr 0.00015 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 80.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  6.03s | mean loss -1.42 | lr 9.259748514523653e-05 | data time  0.00 step time  0.06 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 74.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  5.81s | mean loss -1.28 | lr 4.3933982822017876e-05 | data time  0.00 step time  0.05 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 79.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  6.04s | mean loss -1.48 | lr 1.1418070123306989e-05 | data time  0.00 step time  0.06 forward time  0.01 | max gpu mem 0.9 GiB | gpu utilization 77.0 %| nan share  0.00 ignore share (for classification tasks) 0.0000
# -----------------------------------------------------------------------------------------

# %% [markdown]
# If you see "nan" in the positional losses in the training log above that just means this particular `single_eval_pos` was not sampled.

# %%
# our model wants the seq dimension first, remember that!

batch_index = 0 # change this to see other examples
num_training_points = 50

train_x = batch.x[batch_index, :num_training_points]
train_y = batch.y[batch_index, :num_training_points]
test_x = batch.x[batch_index]

with torch.no_grad():
    # we add our batch dimension, as our transformer always expects that
    logits = trained_model_anti_sine(train_x[None], train_y[None], test_x[None])

# the model has the criterion still attached (it is the same though, as our criterion above)
# the criterion has a lot of handy function to use these logits
pred_means = trained_model_anti_sine.criterion.mean(logits)[0]
pred_confs = trained_model_anti_sine.criterion.quantile(logits)[0]


plt.scatter(train_x[...,0],train_y)
order_test_x = test_x[...,0].argsort()
plt.plot(test_x[order_test_x, ..., 0],pred_means[order_test_x], color='green', label='pfn')
plt.fill_between(test_x[order_test_x, ..., 0], pred_confs[..., 0][order_test_x], pred_confs[...,1][order_test_x], alpha=.1, color='green')

# %% [markdown]
# It looks like we can actually reconstruct the mean of the sine. This might be helpful for some obscure regression with a sine based noise..

# %% [markdown]
# ### ONE ENCORE!! Let's do a GP as finale (and calculate EI on it)
#
# For this we will use a prior that is already part of the pacakge in the `priors` folder. This folder is generally useful to store priors.
#
# You can already have a sneak peak at what we will get out here, in our demo https://huggingface.co/spaces/samuelinferences/transformers-can-do-bayesian-inference
#
# We will start by sampling some datasets in 1d from GP.

# %%
from pfns.priors.fast_gp import get_batch as get_batch_for_gp

batch = get_batch_for_gp(batch_size=2, seq_len=100, num_features=1, hyperparameters={"noise": 1e-4, "outputscale": 1., "lengthscale": 0.1})
for dataset_index in range(len(batch.x)):
    plt.scatter(batch.x[dataset_index,:,0].cpu().numpy(), batch.y[dataset_index,:].cpu().numpy())

# %% [markdown]
# ### Now we can go ahead and train a PFN, let's go 🚂

# %%
from pfns import priors

training_output_gp = train_a_pfn(get_batch_for_gp, hps={"noise": 1e-4, "outputscale": 1., "lengthscale": 0.1})
trained_model_gp = training_output_gp['model']

# %%
# our model wants the seq dimension first, remember that!

batch = get_batch_for_gp(batch_size=2, seq_len=100, num_features=1, hyperparameters={"noise": 1e-4, "outputscale": 1., "lengthscale": 0.1})

batch_index = 0 # change this to see other examples
num_training_points = 5

train_x = batch.x[batch_index, :num_training_points].cpu()
train_y = batch.y[batch_index, :num_training_points].cpu()
test_x = batch.x[batch_index].cpu()

with torch.no_grad():
    # we add our batch dimension, as our transformer always expects that
    logits = trained_model_gp(train_x[None], train_y[None], test_x[None])

# the model has the criterion still attached (it is the same though, as our criterion above)
# the criterion has a lot of handy function to use these logits
pred_means = trained_model_gp.criterion.mean(logits)[0]
pred_confs = trained_model_gp.criterion.quantile(logits)[0]

plt.scatter(train_x[...,0],train_y)
order_test_x = test_x[...,0].argsort()
plt.plot(test_x[order_test_x, ..., 0],pred_means[order_test_x], color='green', label='pfn')
plt.fill_between(test_x[order_test_x, ..., 0], pred_confs[..., 0][order_test_x], pred_confs[...,1][order_test_x], alpha=.1, color='green')

### WE CAN CALCULATE THE EI LIKE THIS:
pred_ei = trained_model_gp.criterion.ei(logits, best_f=max(train_y))

plt.figure()
plt.title('EI')
plt.plot(test_x[order_test_x, ..., 0], pred_ei[0,order_test_x], color='green', label='ei')
plt.show()
